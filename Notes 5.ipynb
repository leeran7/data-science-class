# %%
import pandas as pd
import numpy as np

# %%
pres = pd.read_csv("president_heights.csv")

# %%
pres.head()
# Out:
#    order               name  height(cm)
# 0      1  George Washington         189
# 1      2         John Adams         170
# 2      3   Thomas Jefferson         189
# 3      4      James Madison         163
# 4      5       James Monroe         183

# %%
pres['height(in)'] = pres['height(cm)'] * 0.393701

# %%
pres[pres['height(in)'] < 67]
# Out:
#     order               name  height(cm)  height(in)
# 1       2         John Adams         170   66.929170
# 3       4      James Madison         163   64.173263
# 7       8   Martin Van Buren         168   66.141768
# 21     23  Benjamin Harrison         168   66.141768
# 22     25   William McKinley         170   66.929170

# %%
pres.sort_values(by='height(in)').head()
# Out:
#     order               name  height(cm)  height(in)
# 3       4      James Madison         163   64.173263
# 21     23  Benjamin Harrison         168   66.141768
# 7       8   Martin Van Buren         168   66.141768
# 1       2         John Adams         170   66.929170
# 22     25   William McKinley         170   66.929170

# %%
area = pd.Series({'California': 423967, 'Texas': 695662,
                  'New York': 141297, 'Florida': 170312,
                  'Illinois': 149995})
pop = pd.Series({'California': 38332521, 'Texas': 26448193,
                 'New York': 19651127, 'Florida': 19552860,
                 'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'pop':pop})
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data.loc['California']
# Out:
# area      423967
# pop     38332521
# Name: California, dtype: int64

# %%
data.iloc[0]
# Out:
# area      423967
# pop     38332521
# Name: California, dtype: int64

# %%
data.loc[data.area > 250000]
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193

# %%
pres[pres['height(in)'] > pres['height(in)'].mean()]
# Out:
#     order                   name  height(cm)  height(in)
# 0       1      George Washington         189   74.409489
# 2       3       Thomas Jefferson         189   74.409489
# 4       5           James Monroe         183   72.047283
# 6       7         Andrew Jackson         185   72.834685
# 9      10             John Tyler         183   72.047283
# 14     15         James Buchanan         183   72.047283
# 15     16        Abraham Lincoln         193   75.984293
# 19     20      James A. Garfield         183   72.047283
# 20     21      Chester A. Arthur         183   72.047283
# 24     27    William Howard Taft         182   71.653582
# 26     29      Warren G. Harding         183   72.047283
# 28     31         Herbert Hoover         182   71.653582
# 29     32  Franklin D. Roosevelt         188   74.015788
# 32     35        John F. Kennedy         183   72.047283
# 33     36      Lyndon B. Johnson         193   75.984293
# ...

# %%
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data.drop('Texas')
# Out:
#               area       pop
# California  423967  38332521
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data.drop("area", axis=1)
# Out:
#                  pop
# California  38332521
# Texas       26448193
# New York    19651127
# Florida     19552860
# Illinois    12882135

# %%
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
#gets array of indexed that fit the criteria
data.loc[data['area'] > 250000].index
# Out:
# Index(['California', 'Texas'], dtype='object')

# %%
#drops the same array from array above
data.drop(data.loc[data['area'] > 250000].index)
# Out:
#             area       pop
# New York  141297  19651127
# Florida   170312  19552860
# Illinois  149995  12882135
