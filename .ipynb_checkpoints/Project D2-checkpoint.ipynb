# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("AB_NYC_2019.csv")

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#top 5 host_id price averages
df.groupby(["host_id", "host_name"])['price'].mean().sort_values(ascending=False).head()
# Out:
# host_id   host_name
# 20582832  Kathrine     10000.0
# 5143901   Erin         10000.0
# 72390391  Jelena       10000.0
# 4382127   Matt          9999.0
# 3906464   Amy           9999.0
# Name: price, dtype: float64

# %% [markdown]
# # What is the max rental price?

# %%
maxPrice = df['price'].max()
maxPrice
# Out:
# 10000

# %% [markdown]
# # What listings have the highest rental prices?

# %%
highestRents = df[df['price'] == maxPrice]
highestRents
# Out:
#              id                                             name   host_id  \
# 9151    7003697              Furnished room in Astoria apartment  20582832
# 17692  13894339  Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                              1-BR Lincoln Center  72390391
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 29238    Jelena           Manhattan  Upper West Side  40.77213  -73.98665
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 9151      Private room  10000             100                  2  2016-02-13
# 17692  Entire home/apt  10000               5                  5  2017-07-27
# 29238  Entire home/apt  10000              30                  0         NaN
#
# ...

# %% [markdown]
# # What are the Host Id's of the highest rentals?

# %%
highestRents['host_id'].values
# Out:
# array([20582832,  5143901, 72390391])

# %% [markdown]
# # What is the Heatmap of the data?

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
from scipy import stats

# %% [markdown]
# # Lets retrieve the outliers in terms of price

# %%
twentyFifth = df['price'].quantile(.25)
seventyFifth = df['price'].quantile(.75)
inner = seventyFifth - twentyFifth;
upperOutliers = inner * 1.5 + seventyFifth;
df[df['price'] > upperOutliers]
# Out:
#              id                                               name    host_id  \
# 61        15396                 Sunny & Spacious Chelsea Apartment      60278
# 85        19601                perfect for a family or small group      74303
# 103       23686  2000 SF 3br 2bath West Village private  townhouse      93790
# 114       26933  2 BR / 2 Bath Duplex Apt with patio! East Village      72062
# 121       27659                   3 Story Town House in Park Slope     119588
# ...         ...                                                ...        ...
# 48758  36420289    Rustic Garden House Apt, 2 stops from Manhattan   73211393
# 48833  36450896   Brand New 3-Bed Apt in the Best Location of FiDi   29741813
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
# 48842  36453160  LUXURY MANHATTAN PENTHOUSE+HUDSON RIVER+EMPIRE...  224171371
# 48856  36457700  Large 3 bed, 2 bath , garden , bbq , all you need   66993395
#
# ...

# %% [markdown]
# # What is the distribution like for prices?

# %%
#boxplot before minimum nights higher than 14 removed

plt.boxplot(df['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7c49bb8cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f7c4a14b370>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7c49bb8880>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7c4a14ba90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7c4a14be20>],
#  'means': []}

# %% [markdown]
# # Lets only take into account listings with minimum_nights under 14, maybe this will help the distribution oof the blox plot

# %%
drop_high_minimum_nights = df[df['minimum_nights'] > 14]
df.drop(drop_high_minimum_nights.index, inplace=True)
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# # Redo Boxplot

# %%
#boxplot before zeroes removed

plt.boxplot(df['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7c49ff5640>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f7c49ff5d60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7c49ff52b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7c4a0014c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7c4a001850>],
#  'means': []}

# %% [markdown]
# # Lets try removing pricing where its zero

# %%
zeroPricing = df[df['price'] == 0]
df.drop(zeroPricing.index, inplace=True)
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# # Did not help very much

# %%
#boxplot before outliers removal

plt.boxplot(df['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7c4a69c640>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f7c4a69cd60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7c4a69c2b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7c4a6a94c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7c4a6a9850>],
#  'means': []}

# %% [markdown]
# # Sort prices from highest to lowest

# %%
df.sort_values('price', ascending=False)
# Out:
#              id                                             name    host_id  \
# 17692  13894339  Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 6530    4737930                               Spanish Harlem Apt    1235070
# 4377    2953058                                    Film Location    1177497
# 29662  22779726        East 72nd Townhouse by (Hidden by Airbnb)  156158778
# 45666  34895693                             Gem of east Flatbush  262534951
# ...         ...                                              ...        ...
# 23256  18835820           Quiet, Cozy UES Studio Near the Subway   52777892
# 33225  26235873                           Voted #1 Airbnb In NYC  197169969
# 31066  24114389  Very Spacious bedroom, steps from CENTRAL PARK.  180661875
# 35386  28071998               Cozy room in a three-bedroom House   47516406
# 47218  35642891                       Beautiful room in Bushwick  268138154
#
# ...

# %% [markdown]
# # What is the average of prices for each borough?

# %%
df.groupby('neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx             88.721848
# Brooklyn         125.093547
# Manhattan        191.545731
# Queens            99.759853
# Staten Island    116.461756
# Name: price, dtype: float64

# %% [markdown]
# # Lets take a look at the map of where minimum_nights is lowest to highest

# %%
#areas with highest minimum_nights available before outliers removal

sns.set(rc = {'figure.figsize':(15,8)})
sns.scatterplot(data=df, x='latitude', y='longitude', hue='minimum_nights')
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# # Lets remove the outliers and see how the map changes, including the boxplot

# %%
twentyFifth = df['price'].quantile(.25)
seventyFifth = df['price'].quantile(.75)
inner = seventyFifth - twentyFifth;
upperOutliers = inner * 1.5 + seventyFifth;
outliers = df[df['price'] > upperOutliers]
df.drop(outliers.index, inplace=True)

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# # Map is almost un changed

# %%
#areas with highest minimum_nights available after outliers removal

sns.set(rc = {'figure.figsize':(15,8)})
sns.scatterplot(data=df, x='latitude', y='longitude', hue='minimum_nights')
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# # Box plot is looking a lot more normal now. Still a lot of outliers on the higher end

# %%
plt.boxplot(df['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7c4cd76130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f7c4cd76850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7c4cd88d60>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7c4cd76f70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7c4b3bc370>],
#  'means': []}

# %% [markdown]
# # What is the mean price for all listings

# %%
df.groupby('neighbourhood_group')['price'].mean().mean()
# Out:
# 101.74970445482536

# %%
sns.catplot(x = 'neighbourhood_group', y='price', data = df )

# %% [markdown]
# # What are the 5 hosts with the highest average listings?

# %%
df.groupby('host_id')['price'].mean().sort_values(ascending=False).head()
# Out:
# host_id
# 412783       334.0
# 29065752     333.0
# 269146714    333.0
# 62031986     333.0
# 224001464    333.0
# Name: price, dtype: float64

# %% [markdown]
# # Lets find the boxplot of prices for each boroughs listings

# %%
#boxplot of each boroughs price
sns.set(rc = {'figure.figsize':(20,20)})
sns.boxplot(data=df, y="price", x="neighbourhood_group")
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='price'>

# %% [markdown]
# # Findings
# - There is an abnormal amount of outliers in the price category
#     - I am going to attempt to trim down the data to get it more normalized
#     - I removed prices that were listed as 0, which did not do much to change the boxplot
# - Some airbnbs have an abnormal amount of minimum days to rent
#     - which i ended up removing any listings with larger than 14 days, to retrieve only the short term rentals
#     - This did nothing in attempting to remove outliers in the price category
# - Manhattan has the highest average price of all 5 boroughts, with Staten Island coming at number 3
# - I removed about 3000 outliers, and got a normal boxplot from the normalized data
#     - After normalizing the data, Queens squeaked by staten island in average price cost, with Manhattan still in first.
# - Top 5 hosts with highest average pricesfor their listings

# %% [markdown]
# # Deliverable 3

# %% [markdown]
# # I took your feedback about creating  story about my findings, and added comments before every main piece of data that was generated to give you a sense of my though process between each step of the way.
# # Thank you for enjoying the project! I didnt get too much feedback in terms of changes besides the above, So I will just continue!

# %% [markdown]
# # Findings
#
# ## currently, my findings have no changed very much from the top, but I will be resetting the data and starting from scratch with some new charts to gather some more data

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
sns.histplot(data=df, x='host_id', y='price', hue='minimum_nights' )
# Out:
# <AxesSubplot:xlabel='host_id', ylabel='price'>

# %% [markdown]
# # Lets start from scratch with the data.

# %%
df = pd.read_csv("AB_NYC_2019.csv")

# %% [markdown]
# # Lets see how some graphs look with all of the data

# %%
sns.histplot(data=df, x='host_id', y='price', hue='minimum_nights' )
# Out:
# <AxesSubplot:xlabel='host_id', ylabel='price'>

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# # Lets use Linear Regression to test the data set
# ## Before we run Linear regression, lets clean the data of any strings

# %%
##drop string columns
df.drop(['name', 'host_name', 'last_review', 'neighbourhood', 'neighbourhood_group', 'room_type', 'reviews_per_month'], inplace=True, axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('price', axis=1), df['price'], test_size = .2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_test = lm.predict(X_test)
y_pred_train = lm.predict(X_train)

# %%
residuals = abs(y_test - y_pred_test)
indexes = list(residuals.nlargest(10).index)
worst = y_test[indexes]
test = [y_test.index.get_loc(x) for x in indexes]

# %%
sns.scatterplot(y_test, y_pred_test)
sns.scatterplot(worst, y_pred_test[test], color='red')
# Out:
# /Users/leeranfarin/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/leeranfarin/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>
