# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("occupational-employment-and-wage-statistics-1.csv")
df
# Out:
#       Area Type   Area         Area Name  Standard Occupational Code  \
# 0             1     36    New York State                     00-0000
# 1             1     36    New York State                     11-0000
# 2             1     36    New York State                     11-1011
# 3             1     36    New York State                     11-1021
# 4             1     36    New York State                     11-1031
# ...         ...    ...               ...                         ...
# 6602         10     10  Western New York                     53-7064
# 6603         10     10  Western New York                     53-7065
# 6604         10     10  Western New York                     53-7072
# 6605         10     10  Western New York                     53-7081
# 6606         10     10  Western New York                     53-7199
#
#                              Occupational Title   Employment  Mean Wage  \
# ...

# %% [markdown]
# # Was initially going to try to find a dataset about NYS jobs and which area had the most technology jobs, but couldnt find a dataset that had the info needed. This was my first candidate for the dataset, but I ended up changing gears.

# %%
df = pd.read_csv("AB_NYC_2019.csv")

# %% [markdown]
# # AirBnB
#
# (1) I have been fascinated with AirBnb since hearing of them, wondering what types of rooms people usually rent out along with the the price ranges people usually pay to rent out an AirBnB over a traditional hotel room. I look to use this dataset to get the areas of NY that has a higher rent rate and the sizes of rooms they typically rent.
#
# (2)
#
#     a. I look to use the the data to find out the relationship between price and area of the different areas of nyc for airbnb.
#
#     b. Another question I look to answer is if there are certain areas which have a higher percentage of larger rooms rented, and see if there which of these rooms are owned by the same person.
#
# (3) I will be using the <a href="https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data">Kaggle AirBnB Dataset </a>.
#
# (4) Some data that this dataset holds are the hosts id number, how many days out of the year the unit is available, the size of the unit, location, neighborhood and room size. The types of this data are a mixture of strings, integers and floats.

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.groupby(by='neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64
